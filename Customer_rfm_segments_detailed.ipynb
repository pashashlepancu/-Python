# %% [markdown]
# ![image.png](attachment:fc313903-4deb-4cb2-9765-d3aefd3273e4.png)

# %% [markdown]
# ## Сыллка на дашборд в Datalens

# %% [markdown]
# https://datalens.yandex/s4oks9wqwzg2d

# %%
# Ну это я попросил в датафрейм мою эксель таблицу переда=елать гпт, не знаю зачем
import pandas as pd
data = [{'Пользователи и контекст': 'Заказчик 1','Понимание задачи': 'Отслеживать динамику ROI сайта и не допускать его ухода в отрицательные значения','Вопросы, бизнес решения': 'Какова текущая рентабельность (ROI) сайта?','Варианты визуализации': 'Столбчатый график: ROI по категориям товаров','Необходимые срезы': 'Динамика (по времени)'},{'Пользователи и контекст': 'Заказчик 1','Понимание задачи': 'Отслеживать динамику ROI сайта и не допускать его ухода в отрицательные значения','Вопросы, бизнес решения': 'Уходит ли ROI в отрицательные значения?','Варианты визуализации': 'Карточка с текущим значением ROI и средним чеком (за последний месяц)','Необходимые срезы': 'По категориям товаров'}, {'Пользователи и контекст': 'Заказчик 1','Понимание задачи': 'Понимать, что влияет на изменение ROI — средний чек, расходы, прибыль','Вопросы, бизнес решения': '','Варианты визуализации': 'Столбчатый график: выручка в разрезе на прибыль и расходы по категориям товаров и по времени','Необходимые срезы': 'По гендеру'}, {'Пользователи и контекст': 'Заказчик 1','Понимание задачи': 'Понимать, что влияет на изменение ROI — средний чек, расходы, прибыль','Вопросы, бизнес решения': '','Варианты визуализации': 'Столбчатый график: средний чек по возрасту и гендеру','Необходимые срезы': 'По возрастным группам'},{'Пользователи и контекст': 'Заказчик 1','Понимание задачи': '','Вопросы, бизнес решения': '','Варианты визуализации': 'Линейный график: динамика среднего чека','Необходимые срезы': ''}, {'Пользователи и контекст': 'Заказчик 2','Понимание задачи': 'Выполнять плановое значение ARPPU ≥ 1950','Вопросы, бизнес решения': 'Выполняется ли плановое значение ARPPU ≥ 1950?','Варианты визуализации': 'Гистограмма: динамика ARPPU по месяцам и годам','Необходимые срезы': 'По категориям товаров'},{'Пользователи и контекст': 'Заказчик 2','Понимание задачи': 'Выполнять плановое значение ARPPU ≥ 1950','Вопросы, бизнес решения': 'Какие категории товаров являются убыточными (расходы > доходы)?','Варианты визуализации': 'RFM круговая диаграмма','Необходимые срезы': 'Динамика (по времени)'},{'Пользователи и контекст': 'Заказчик 2','Понимание задачи': 'Выявлять убыточные категории/бренды и либо убирать их, либо запускать кампании по продвижению','Вопросы, бизнес решения': 'Какие товары показывают низкий спрос и требуют усиленного продвижения?','Варианты визуализации': 'Гистограмма: ARPPU по категориям товаров','Необходимые срезы': ''},{'Пользователи и контекст': 'Заказчик 2','Понимание задачи': 'Выявлять убыточные категории/бренды и либо убирать их, либо запускать кампании по продвижению','Вопросы, бизнес решения': 'Есть ли товары, которые стоит полностью убрать с сайта?','Варианты визуализации': 'Карточка с текущим значением ARPU','Необходимые срезы': ''}, {'Пользователи и контекст': 'Заказчик 3','Понимание задачи': 'Контролировать, чтобы цены были «по карману» ЦА','Вопросы, бизнес решения': 'Какова активность и возвращаемость пользователей (повторные покупки)?','Варианты визуализации': 'Линейный график: динамика среднего чека и количества заказов','Необходимые срезы': 'По возрастным группам'},{'Пользователи и контекст': 'Заказчик 3','Понимание задачи': 'Контролировать, чтобы цены были «по карману» ЦА', 'Вопросы, бизнес решения': 'Коррелирует ли рост цены с падением активности?', 'Варианты визуализации': 'Столбчатый график: распределение пользователей по возрастным группам и полу.', 'Необходимые срезы': 'По полу'},{'Пользователи и контекст': 'Заказчик 3','Понимание задачи': 'Понимать особенности аудитории и её возвращаемость (повторные покупки = платёжеспособность)','Вопросы, бизнес решения': 'Как сегментирована наша целевая аудитория (например, по RFM)?','Варианты визуализации': 'Столбчатый график: средний чек по локации и полу','Необходимые срезы': 'По городу (локации)'},{'Пользователи и контекст': 'Заказчик 3','Понимание задачи': 'Понимать особенности аудитории и её возвращаемость (повторные покупки = платёжеспособность)','Вопросы, бизнес решения': 'Соответствуют ли текущие цены платежеспособности и ожиданиям ЦА?','Варианты визуализации': 'Карточка с текущим значением среднего чека','Необходимые срезы': 'Динамика (по времени)' }]
# Создаём DataFrame
df_plan = pd.DataFrame(data)
df_plan
# Out:
#    Пользователи и контекст                                   Понимание задачи  \
# 0               Заказчик 1  Отслеживать динамику ROI сайта и не допускать ...
# 1               Заказчик 1  Отслеживать динамику ROI сайта и не допускать ...
# 2               Заказчик 1  Понимать, что влияет на изменение ROI — средни...
# 3               Заказчик 1  Понимать, что влияет на изменение ROI — средни...
# 4               Заказчик 1
# 5               Заказчик 2           Выполнять плановое значение ARPPU ≥ 1950
# 6               Заказчик 2           Выполнять плановое значение ARPPU ≥ 1950
# 7               Заказчик 2  Выявлять убыточные категории/бренды и либо уби...
# 8               Заказчик 2  Выявлять убыточные категории/бренды и либо уби...
# 9               Заказчик 3    Контролировать, чтобы цены были «по карману» ЦА
# 10              Заказчик 3    Контролировать, чтобы цены были «по карману» ЦА
# 11              Заказчик 3  Понимать особенности аудитории и её возвращаем...
# ...

# %%
import os
import pandas as pd

os.chdir(r'C:\Users\pasht\OneDrive\Документы\4 курс 1 семестр\визуализация данных\практика 4')
online_ecom = pd.read_csv('Online ecom.csv', sep=';')
online_ecom[:3]
# Out:
#       CID         TID  Gender     Age Group     Purchase Date  \
# 0  943146  5876328741  Female         25-45  30.08.2023 20:27
# 1  180079  1018503182    Male         25-45   23.02.2024 9:33
# 2  337580  3814082218  Female  60 and above   06.03.2022 9:09
#
#   Product Category Discount Availed    Discount Name  Discount Amount (INR)  \
# 0      Electronics              Yes        FESTIVE50                  64.30
# 1      Electronics              Yes  SEASONALOFFER21                 175.19
# 2         Clothing              Yes  SEASONALOFFER21                 211.54
#
#    Gross Amount   Net Amount Purchase Method   Location
# 0    725.304000   661.004000     Credit Card  Ahmedabad
# 1   4638.991875  4463.801875     Credit Card  Bangalore
# 2   1986.372575  1774.832575     Credit Card      Delhi

# %%
#видим что Purchase Date не в формате datetime
online_ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CID                    55000 non-null  int64
#  1   TID                    55000 non-null  int64
#  2   Gender                 55000 non-null  object
#  3   Age Group              55000 non-null  object
#  4   Purchase Date          55000 non-null  object
#  5   Product Category       55000 non-null  object
#  6   Discount Availed       55000 non-null  object
#  7   Discount Name          27415 non-null  object
#  8   Discount Amount (INR)  55000 non-null  float64
#  9   Gross Amount           55000 non-null  float64
#  10  Net Amount             55000 non-null  float64
#  11  Purchase Method        55000 non-null  object
#  12  Location               55000 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 5.5+ MB

# %%
#прератим Purchase Date в формат datetime используюя normalize для обнуления времени, чтобы оставить только саму дату
online_ecom['Purchase Date']=pd.to_datetime(online_ecom['Purchase Date'], format = '%d.%m.%Y %H:%M').dt.normalize()
online_ecom.info()
online_ecom['Purchase Date'][:3]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CID                    55000 non-null  int64
#  1   TID                    55000 non-null  int64
#  2   Gender                 55000 non-null  object
#  3   Age Group              55000 non-null  object
#  4   Purchase Date          55000 non-null  datetime64[ns]
#  5   Product Category       55000 non-null  object
#  6   Discount Availed       55000 non-null  object
#  7   Discount Name          27415 non-null  object
#  8   Discount Amount (INR)  55000 non-null  float64
#  9   Gross Amount           55000 non-null  float64
#  10  Net Amount             55000 non-null  float64
#  11  Purchase Method        55000 non-null  object
#  12  Location               55000 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(7)
# ...

# %%
online_ecom['count_of_purchase'] = online_ecom['CID']
RFM = online_ecom.groupby('CID').agg({'count_of_purchase':'count', 'Purchase Date':'max', 'Net Amount':'sum'})
RFM.rename(columns = {'Purchase Date':'last_purchase', 'Net Amount':'total_amount'}, inplace = True)
RFM.sort_values(by = 'last_purchase', ascending = False, inplace = True)
RFM[:3]
# Out:
#         count_of_purchase last_purchase  total_amount
# CID
# 401437                  2    2024-09-18    1916.20950
# 871440                  2    2024-09-18    3375.73975
# 116470                  1    2024-09-18    3495.90000

# %%
RFM['last_purchase']=pd.to_datetime(RFM['last_purchase'], format = '%d.%m.%Y')
RFM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29071 entries, 401437 to 478035
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   count_of_purchase  29071 non-null  int64
#  1   last_purchase      29071 non-null  datetime64[ns]
#  2   total_amount       29071 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 908.5 KB

# %%
RFM['max_date'] = RFM['last_purchase'].max()
RFM['days_since_last_order'] = RFM['max_date']-RFM['last_purchase']
RFM['days_since_last_order'] = RFM['days_since_last_order'].dt.days
RFM[:3]
# Out:
#         count_of_purchase last_purchase  total_amount   max_date  \
# CID
# 401437                  2    2024-09-18    1916.20950 2024-09-18
# 871440                  2    2024-09-18    3375.73975 2024-09-18
# 116470                  1    2024-09-18    3495.90000 2024-09-18
#
#         days_since_last_order
# CID
# 401437                      0
# 871440                      0
# 116470                      0

# %%
RFM.loc[889269]
# Out:
# count_of_purchase                          1
# last_purchase            2023-12-18 00:00:00
# total_amount                       1059.8504
# max_date                 2024-09-18 00:00:00
# days_since_last_order                    275
# Name: 889269, dtype: object

# %%
q1 = RFM['days_since_last_order'].quantile(0.25)
q3 = RFM['days_since_last_order'].quantile(0.75)
RFM['Recency'] = ''

#сделаем через loc чтобы вспомнить loc, удобнее конечно делать через qcut()
RFM.loc[RFM['days_since_last_order']<=q1, 'Recency']=3
RFM.loc[(RFM['days_since_last_order']>q1) & (RFM['days_since_last_order']<q3), 'Recency']=2
RFM.loc[RFM['days_since_last_order']>=q3, 'Recency']=1
#RFM.rename(columns = {'days_since_last_order':'Recency'}, inplace = True)
RFM[:3]
# Out:
#         count_of_purchase last_purchase  total_amount   max_date  \
# CID
# 401437                  2    2024-09-18    1916.20950 2024-09-18
# 871440                  2    2024-09-18    3375.73975 2024-09-18
# 116470                  1    2024-09-18    3495.90000 2024-09-18
#
#         days_since_last_order Recency
# CID
# 401437                      0       3
# 871440                      0       3
# 116470                      0       3

# %%
#остальные разобьем через cut и qcut 
RFM['Frequency'] = pd.cut(RFM['count_of_purchase'],bins=[0, 2, 6, 9],labels=[3, 2, 1])
RFM['Monetary'] = pd.qcut(RFM.total_amount, q = [0,0.25,0.75,1], labels = [3,2,1])
RFM[:3]
# Out:
#         count_of_purchase last_purchase  total_amount   max_date  \
# CID
# 401437                  2    2024-09-18    1916.20950 2024-09-18
# 871440                  2    2024-09-18    3375.73975 2024-09-18
# 116470                  1    2024-09-18    3495.90000 2024-09-18
#
#         days_since_last_order Recency Frequency Monetary
# CID
# 401437                      0       3         3        3
# 871440                      0       3         3        2
# 116470                      0       3         3        2

# %%
RFM['RFM'] = (RFM['Recency'].astype(str) + RFM['Frequency'].astype(str) + RFM['Monetary'].astype(str))
RFM[:3]
# Out:
#         count_of_purchase last_purchase  total_amount   max_date  \
# CID
# 401437                  2    2024-09-18    1916.20950 2024-09-18
# 871440                  2    2024-09-18    3375.73975 2024-09-18
# 116470                  1    2024-09-18    3495.90000 2024-09-18
#
#         days_since_last_order Recency Frequency Monetary  RFM
# CID
# 401437                      0       3         3        3  333
# 871440                      0       3         3        2  332
# 116470                      0       3         3        2  332

# %%
display(RFM['Recency'].value_counts(),
        RFM['Frequency'].value_counts(),
        RFM['Monetary'].value_counts())
# Out:
# Recency
# 2    14508
# 3     7285
# 1     7278
# Name: count, dtype: int64
# Frequency
# 3    22388
# 2     6636
# 1       47
# Name: count, dtype: int64
# Monetary
# 2    14535
# 3     7268
# 1     7268
# Name: count, dtype: int64

# %% [markdown]
# ## Вывод: Т.к анализируемые данные имеют лежат в интарвале времени 5 лет, а кол-во клиентов совершающих от 6 и более заказов крайне низкое, компания предоставляет услуги с низкой частотой потребления

# %%
RFM.to_csv(
    'RFM_analysis.csv',           # имя файла
    sep=';',                      # разделитель — точка с запятой
    index=True,                  # без индекса
    encoding='utf-8',             # поддержка русских букв
    decimal='.'                   # числа с точкой (если нужна запятая — ставь ',')
)

# %%
RFM[RFM['RFM'] == '111'] #нету потому что в компании очень мало людей совершивших от 6 до 9 заказов
# Out:
# Empty DataFrame
# Columns: [count_of_purchase, last_purchase, total_amount, max_date, days_since_last_order, Recency, Frequency, Monetary, RFM]
# Index: []
